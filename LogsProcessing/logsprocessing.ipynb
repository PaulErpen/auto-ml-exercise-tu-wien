# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.patches as patches

# %% [markdown]
# # Elastic Net

# %%
beijing_elasticnet = pd.read_csv(
    "../output/beijing/ElasticNetManager.csv", 
    names=["timestamp","temperature","rmse","alpha","l1","is_best","is_current"])
display(beijing_elasticnet)
# Out:
#         timestamp  temperature         rmse     alpha        l1  is_best  \
# 0        1.577320     0.999771  6204.491847  1.000000  0.851024    False
# 1       15.928721     0.999562  6149.367335  0.000000  1.000000     True
# 2       16.508600     0.995575  6168.777286  0.240987  0.596923    False
# 3       17.344817     0.995414  6205.483902  0.493684  0.413723    False
# 4       17.995352     0.995182  6196.962464  0.403080  0.411840    False
# ...           ...          ...          ...       ...       ...      ...
# 1258  3580.574892     0.006290  6150.962984  0.001703  0.034692    False
# 1259  3584.224961     0.005396  6150.284796  0.004469  0.032659    False
# 1260  3589.835185     0.004382  6149.148169  0.001999  0.033437    False
# 1261  3593.274734     0.002824  6148.409616  0.002811  0.036504    False
# 1262  3601.109252     0.001868  6149.620284  0.000842  0.035760    False
#
#       is_current
# 0          False
# 1           True
# 2          False
# 3          False
# 4          False
# ...          ...
# 1258       False
# 1259       False
# 1260       False
# 1261       False
# 1262       False
#
# [1263 rows x 7 columns]

# %%
fig, ax = plt.subplots()
scatter = ax.scatter(beijing_elasticnet["alpha"], beijing_elasticnet["rmse"], c=beijing_elasticnet["l1"])
plt.title("Elastic Net - Parameter tuning")
ax.legend(*scatter.legend_elements(), title="L1 Penalty", loc='center left', bbox_to_anchor=(1, 0.5))
plt.xlabel("Alpha")
plt.ylabel("MSE")
plt.show()

# %%
beijing_current = beijing_elasticnet[beijing_elasticnet["is_current"] == True]
beijing_best = beijing_elasticnet[beijing_elasticnet["is_best"] == True]
plt.scatter(beijing_elasticnet["timestamp"], beijing_elasticnet["rmse"], c="blue")
plt.scatter(beijing_current["timestamp"], beijing_current["rmse"], c="orange")
plt.scatter(beijing_best["timestamp"], beijing_best["rmse"], c="red")
plt.title("Elastic Net - Parameter tuning")
plt.xlabel("Time since start in seconds")
plt.ylabel("MSE")
plt.legend(title="Result type", handles=[patches.Patch(color="blue", label="Normal"), patches.Patch(color="red", label="Best"), patches.Patch(color="orange", label="current")])

# %% [markdown]
# # Neural Network

# %%
beijing_mlp = pd.read_csv(
    "../output/beijing/MlpManager.csv", 
    names=["timestamp","temperature","rmse","n_neurons_l1","n_neurons_l2","alpha","l1","is_best","is_current"])
display(beijing_mlp)
# Out:
#       timestamp  temperature         rmse  n_neurons_l1  n_neurons_l2  \
# 0    120.164072     0.983408  5733.126305             7             7
# 1    212.382282     0.966621  5456.308067            21            28
# 2    282.271015     0.941005  5795.608327            23            17
# 3    378.324602     0.921591  5826.105791            13            25
# 4    438.483882     0.894910  5791.214482             7            20
# 5    507.570184     0.878199  5580.894580            28            14
# 6    589.744211     0.859008  5590.685249            28             8
# 7    619.726017     0.836182  6214.752161             7            27
# 8    691.689214     0.827854  5700.645252            28            13
# 9    810.073194     0.807864  5474.265359            23            21
# 10   858.086341     0.774980  6040.481400             7            16
# 11   888.305188     0.761643  6165.943567            22            11
# 12   934.394617     0.753249  5636.131657            26            10
# 13   992.192062     0.740446  5697.681209            17             8
# 14  1050.888268     0.724391  5279.011054            28            17
# 15  1119.595504     0.708087  5442.126718            15            16
# 16  1153.470427     0.689001  5566.180938             9            11
# 17  1243.836207     0.679592  5047.196564            23            28
# 18  1324.014161     0.654490  5305.165334            28            22
# 19  1400.127249     0.632218  5517.180637            26            17
# 20  1488.561350     0.611076  5592.615156            25            23
# 21  1542.665252     0.586511  5474.172148            20            27
# 22  1583.071495     0.571482  5460.723263            28            16
# 23  1649.391085     0.560258  5379.640904            25            21
# 24  1697.184527     0.541836  5651.802035            19            27
# 25  1774.110775     0.528560  5353.551644            28            23
# 26  1837.722757     0.507191  5401.413755            23            27
# 27  1892.160785     0.489521  5545.045344            28            20
# 28  1984.048856     0.474400  5461.161719            28            18
# 29  2030.281649     0.448875  5629.431088            16            21
# 30  2108.650218     0.436033  5681.341199            28            21
# 31  2185.967315     0.414264  5474.428945            13            16
# 32  2264.256149     0.392787  5564.434961            28            26
# 33  2341.739869     0.371040  5587.495820            23            20
# 34  2407.984639     0.349517  5512.979914            27            24
# 35  2456.009677     0.331115  5611.880225            22            25
# 36  2509.181423     0.317775  5601.174830            17            19
# 37  2551.468716     0.303005  5754.088004            14            21
# 38  2612.984764     0.291259  5398.155977            27            27
# 39  2681.507682     0.274171  5621.449688            19            26
# 40  2775.548843     0.255137  5366.989609            20            27
# 41  2859.278766     0.229014  5562.064834            25            23
# 42  2941.866739     0.205756  5874.375948            26            23
# 43  3016.050680     0.182815  5576.587274            27            25
# 44  3101.724263     0.162208  5274.256684            20            24
# 45  3184.424932     0.138410  5492.555586            21            25
# 46  3274.587018     0.115438  5336.740715            24            27
# 47  3357.945880     0.090392  5874.224090            23            27
# 48  3444.987043     0.067237  5372.251179            21            27
# 49  3489.804127     0.043059  5774.802450            22            27
# 50  3581.634439     0.030610  5333.945257            23            27
# 51  3612.552567     0.005102  5494.508479            23            27
#
#        alpha     l1  is_best  is_current
# 0   0.000000   True     True         NaN
# 1   0.612527   True     True         NaN
# 2   0.771938  False    False         NaN
# 3   0.075537  False    False         NaN
# 4   0.508030  False    False         NaN
# 5   1.000000  False    False         NaN
# 6   0.549091  False    False         NaN
# 7   0.596563  False    False         NaN
# 8   0.039955  False    False         NaN
# 9   0.015470  False    False         NaN
# 10  1.000000  False    False         NaN
# 11  1.000000  False    False         NaN
# 12  0.369920  False    False         NaN
# 13  0.866122  False    False         NaN
# 14  0.766464   True     True         NaN
# 15  0.120619  False    False         NaN
# 16  1.000000  False    False         NaN
# 17  1.000000   True     True         NaN
# 18  0.677487  False    False         NaN
# 19  0.928355  False    False         NaN
# 20  0.815722  False    False         NaN
# 21  0.993917  False    False         NaN
# 22  0.529826  False    False         NaN
# 23  0.763962  False    False         NaN
# 24  0.600301  False    False         NaN
# 25  0.570122  False    False         NaN
# 26  0.677362  False    False         NaN
# 27  0.579696  False    False         NaN
# 28  0.839929  False    False         NaN
# 29  0.988543  False    False         NaN
# 30  0.994109  False    False         NaN
# 31  0.822301  False    False         NaN
# 32  0.806366  False    False         NaN
# 33  0.854000  False    False         NaN
# 34  0.705145  False    False         NaN
# 35  0.945410  False    False         NaN
# 36  0.921905  False    False         NaN
# 37  0.905421  False    False         NaN
# 38  0.887439  False    False         NaN
# 39  0.893554  False    False         NaN
# 40  0.931885  False    False         NaN
# 41  0.839806  False    False         NaN
# 42  0.896074  False    False         NaN
# 43  0.915260  False    False         NaN
# 44  0.950691  False    False         NaN
# 45  0.948235  False    False         NaN
# 46  0.911627  False    False         NaN
# 47  0.983836  False    False         NaN
# 48  0.972969  False    False         NaN
# 49  0.957936  False    False         NaN
# 50  0.979066  False    False         NaN
# 51  0.997741  False    False         NaN

# %%
plt.scatter(beijing_mlp["timestamp"], beijing_mlp["n_neurons_l1"])
plt.scatter(beijing_mlp["timestamp"], beijing_mlp["n_neurons_l2"])
